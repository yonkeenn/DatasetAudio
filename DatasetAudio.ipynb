# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as     plt
from scipy.stats import zscore
import pytube as videodw
import soundfile as sf

# %%
list = {
    "https://www.youtube.com/watch?v=c_McoKRL-dk",
    "https://www.youtube.com/watch?v=k9rzsQH-OPE",
    "https://www.youtube.com/watch?v=E4fQih6mNIU",
    "https://www.youtube.com/watch?v=y4_hvjX_XII",
    "https://www.youtube.com/watch?v=rIq5C4LemsA",
    "https://www.youtube.com/watch?v=PgYcojRcjSU",
    "https://www.youtube.com/watch?v=Ob7yHhs1zVw",
    "https://www.youtube.com/watch?v=YskwP8tj3wU",
    "https://www.youtube.com/watch?v=ZuIpq2M8p_s"}
        
for i in list:
    yt = videodw.YouTube(i)
    yt.streams.first().download("/home/jhon/")

# %%
import librosa
data, fs = librosa.load('./audiosplit_1sec/audio001_mazeti1_000.wav')

# %%
print(data,fs)
# Out:
# [-0.00844041  0.00992975  0.03602054 ... -0.08661809 -0.08665814
#   0.        ] 22050

# %%
sf.write(particionado/viscarra2.wav, segmento, fs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-7dd72ce43953> in <module>
# ----> 1 sf.write(particionado/viscarra2.wav, segmento, fs)
#
# NameError: name 'particionado' is not defined

# %%
print(np.random.randn(10, 2))
# Out:
# [[-0.1563806   0.59756316]
#  [-0.10480001 -1.04619943]
#  [ 1.82924396 -1.21691352]
#  [-1.15064065  0.29182479]
#  [ 0.54376609 -0.9651882 ]
#  [ 1.6763914   0.35933576]
#  [-0.8474193  -0.44193195]
#  [ 0.85270547  0.05398486]
#  [-0.93070352 -0.28525438]
#  [ 1.36435208  1.40731376]]

# %%
import librosa.display

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(data, sr=fs)

# %%
##--Creamos una funcion para extraer las mediciones del audio.

def extract_features(files): 
    # Establece el nombre de la ruta a donde están los archivos de audio en mi computadora
    file_name = os.path.join(os.path.abspath(data_dir)+'//audios_enteros//'+str(files.id))
    
    # Carga el archivo de audio como una serie de tiempo de coma flotante y asigna la frecuencia de muestreo predeterminada
    # Sample rate is set to 22050 by default
    # la serie de tiempo esta almacenada en [X]
    X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    
    # genera Mel-frequency cepstral coefficients (MFCCs) de la serie de tiempo
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    
    # Genera una transformada de Fourier a corto plazo (STFT) para usar en chroma_stft
    stft = np.abs(librosa.stft(X))
    
    # Calcula un cromagrama a partir de una forma de onda o espectrograma de potencia.
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    
    # calcula un espectograma de mel-scaled 
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    
    # Calcula el contraste espectral
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    
    # Calcula las características del centroide tonal (tonnetz)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),sr=sample_rate).T,axis=0)
    
    # Agregamos también las clases de cada archivo como una etiqueta al final
    label = files.persona
    # Pedimos que nos devuelva todos los indicadores mas el target
    
    return mfccs, chroma, mel, contrast, tonnetz,label

# %%
list = {
    "https://www.youtube.com/watch?v=rOe3tYJ1LAQ",
    "https://www.youtube.com/watch?v=Y5kKPIhdsfE",
    "https://www.youtube.com/watch?v=7cWcPhRLtl4",
    "https://www.youtube.com/watch?v=-TRB8L1DrFQ",
    "https://www.youtube.com/watch?v=434vp_yfN94",
    "https://www.youtube.com/watch?v=Qas8VzFDYNo",
    "https://www.youtube.com/watch?v=wMGeXjsXiQI",
    "https://www.youtube.com/watch?v=4h_ONxCTdkQ",
    "https://www.youtube.com/watch?v=w2cY5YQZeL0"
    }
        
for i in list:
    yt = videodw.YouTube(i)
    yt.streams.first().download("/home/jhon/")
